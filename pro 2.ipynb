# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
data_set = pd.read_csv('/content/drive/MyDrive/Software Project /Agricultural-Dataset.csv')
#data_set = pd.read_csv('/content/drive/MyDrive/Software Project /Agricultural-Dataset.csv')

# %%
data_set
# Out:
#          District  Year   Area  ...  Max_temperature  Min_temperature  Avg_temp
# 0          dhaka   2008    470  ...             34.2             12.5     23.35
# 1        gazipur   2008   2095  ...             30.2             19.5     24.85
# 2      narsingdi   2008    252  ...             34.2             12.5     23.35
# 3    narayangonj   2008    185  ...             34.2             12.2     23.20
# 4        tangail   2008    497  ...             34.1             10.2     22.15
# ..            ...   ...    ...  ...              ...              ...       ...
# 65     narsingdi   2017    282  ...             27.7             14.5     21.10
# 66   narayangonj   2017    131  ...             28.7             12.2     20.45
# 67       tangail   2017   1085  ...             32.0             12.8     22.40
# 68    mymenshing   2017  20948  ...             31.0             21.2     26.10
# 69   kishoregonj   2017  21395  ...             32.0             12.3     22.15
#
# ...

# %%
data_set.head()
# Out:
#         District  Year  Area  ...  Max_temperature  Min_temperature  Avg_temp
# 0         dhaka   2008   470  ...             34.2             12.5     23.35
# 1       gazipur   2008  2095  ...             30.2             19.5     24.85
# 2     narsingdi   2008   252  ...             34.2             12.5     23.35
# 3   narayangonj   2008   185  ...             34.2             12.2     23.20
# 4       tangail   2008   497  ...             34.1             10.2     22.15
#
# [5 rows x 49 columns]

# %%
sb.countplot(x='Year', data=data_set, hue='AUS')
sb.count

# %%
Area_name = pd.Series(["Dhaka", "Narsindi", "Tangail"])
Area_area = pd.Series(["470", "252", "497"])

# %%
Area_name
# Out:
# 0       Dhaka
# 1    Narsindi
# 2     Tangail
# dtype: object

# %%
Area_area
# Out:
# 0    470
# 1    252
# 2    497
# dtype: object

# %%
Area_data = pd.DataFrame({"Name":Area_name, "Country":Area_area})
Area_data
# Out:
#        Name Country
# 0     Dhaka     470
# 1  Narsindi     252
# 2   Tangail     497

# %%
data_set.dtypes
# Out:
# District                                    object
# Year                                         int64
# Area                                         int64
# Avg_rainfall                                 int64
# AUS                                          int64
# AMAN                                         int64
# BORO                                         int64
# Total Paddy                                  int64
# Wheat                                        int64
# Potato                                       int64
# Jute                                         int64
# Peat                                         int64
# Humidity                                   float64
# Storm                                       object
# UREA                                         int64
# TSP                                          int64
# MP                                           int64
# DAP                                          int64
# ...

# %%
data_set.index
# Out:
# RangeIndex(start=0, stop=70, step=1)

# %%
data_set.columns
# Out:
# Index(['District', 'Year', 'Area', 'Avg_rainfall', 'AUS', 'AMAN', 'BORO',
#        'Total Paddy', 'Wheat', 'Potato', 'Jute', 'Peat', 'Humidity', 'Storm',
#        'UREA', 'TSP', 'MP', 'DAP', 'Total Fertilizer',
#        'Inundationland_Highland', 'Inundationland_mediumhighland',
#        'Inundationland_lowland', 'Inundationland_mediumlowland',
#        'Inundationland_verylowland', 'Miscellaneous Land', 'Made-Land',
#        'Total land ', 'Calcareous Alluvium', 'Noncalcareous Alluvium',
#        'Acid Basin Clay', 'Calcareous Brown Floodplain Soil',
#        'Calcareous Grey Floodplain Soil',
#        'Calcareous Dark Grey Floodplain Soil',
#        'Noncalcareous Grey Floodplain Soil',
#        'Noncalcareous Dark Grey Floodplain Soil',
#        'Noncalcareous Brown Floodplain Soil', 'Shallow Red-Brown Terrace Soil',
#        'Deep Red-Brown Terrace Soil', 'Brown Mottled Terrace Soil',
#        'Shallow Grey Terrace Soil', 'Deep Grey Terrace Soil',
# ...

# %%
data_set.info()         # will show the info of each missing column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 49 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   District                                 70 non-null     object
#  1   Year                                     70 non-null     int64
#  2   Area                                     70 non-null     int64
#  3   Avg_rainfall                             70 non-null     int64
#  4   AUS                                      70 non-null     int64
#  5   AMAN                                     70 non-null     int64
#  6   BORO                                     70 non-null     int64
#  7   Total Paddy                              70 non-null     int64
#  8   Wheat                                    70 non-null     int64
#  9   Potato                                   70 non-null     int64
# ...

# %%
data_set.mean()         # mean function give the average of numarical column
# Out:
# Year                                         2012.500000
# Area                                         8160.842857
# Avg_rainfall                                 1837.800000
# AUS                                         18252.314286
# AMAN                                       189617.114286
# BORO                                       469224.828571
# Total Paddy                                677094.257143
# Wheat                                        4171.171429
# Potato                                      38164.014286
# Jute                                        69622.700000
# Peat                                         2020.242857
# Humidity                                       69.467143
# UREA                                        54897.057143
# TSP                                         15643.000000
# MP                                          15569.885714
# DAP                                          8272.642857
# ...

# %%
data_set.groupby(["District"]).mean()       # grouping data using club name & function groupby
# Out:
#                  Year     Area  ...  Min_temperature  Avg_temp
# District                        ...
#  dhaka         2012.5    557.7  ...           12.980   22.1750
#  gazipur       2012.5   1939.8  ...           12.505   21.5375
#  kishoregonj   2012.5  19830.3  ...           11.881   21.3865
#  mymenshing    2012.5  33438.5  ...           20.970   25.6090
#  narayangonj   2012.5    146.7  ...           13.450   22.0650
#  narsingdi     2012.5    258.1  ...           12.593   21.3910
#  tangail       2012.5    954.8  ...           11.670   21.0650
#
# [7 rows x 47 columns]

# %%
data_set2 = data_set.drop(["Year"],axis= 1 ) 

data_set2.groupby(["District"]).mean()
# Out:
#                   Area  Avg_rainfall  ...  Min_temperature  Avg_temp
# District                              ...
#  dhaka           557.7        1730.0  ...           12.980   22.1750
#  gazipur        1939.8        1941.2  ...           12.505   21.5375
#  kishoregonj   19830.3        1884.7  ...           11.881   21.3865
#  mymenshing    33438.5        1896.0  ...           20.970   25.6090
#  narayangonj     146.7        1781.2  ...           13.450   22.0650
#  narsingdi       258.1        1993.5  ...           12.593   21.3910
#  tangail         954.8        1638.0  ...           11.670   21.0650
#
# [7 rows x 46 columns]

# %%
data_set2.groupby(["District"]).sum()
# Out:
#                  Area  Avg_rainfall  ...  Min_temperature  Avg_temp
# District                             ...
#  dhaka           5577         17300  ...           129.80   221.750
#  gazipur        19398         19412  ...           125.05   215.375
#  kishoregonj   198303         18847  ...           118.81   213.865
#  mymenshing    334385         18960  ...           209.70   256.090
#  narayangonj     1467         17812  ...           134.50   220.650
#  narsingdi       2581         19935  ...           125.93   213.910
#  tangail         9548         16380  ...           116.70   210.650
#
# [7 rows x 46 columns]

# %%
# plotting Data 

data_set["Area"].plot()

# %%
data_set["Area"].hist()

# %%
data_set['District'] = data_set['District'].str.upper()
data_set
# Out:
#          District  Year   Area  ...  Max_temperature  Min_temperature  Avg_temp
# 0          DHAKA   2008    470  ...             34.2             12.5     23.35
# 1        GAZIPUR   2008   2095  ...             30.2             19.5     24.85
# 2      NARSINGDI   2008    252  ...             34.2             12.5     23.35
# 3    NARAYANGONJ   2008    185  ...             34.2             12.2     23.20
# 4        TANGAIL   2008    497  ...             34.1             10.2     22.15
# ..            ...   ...    ...  ...              ...              ...       ...
# 65     NARSINGDI   2017    282  ...             27.7             14.5     21.10
# 66   NARAYANGONJ   2017    131  ...             28.7             12.2     20.45
# 67       TANGAIL   2017   1085  ...             32.0             12.8     22.40
# 68    MYMENSHING   2017  20948  ...             31.0             21.2     26.10
# 69   KISHOREGONJ   2017  21395  ...             32.0             12.3     22.15
#
# ...

# %%
data_set_shuffled =data_set.sample(frac=1)

data_set_shuffled
# Out:
#          District  Year   Area  ...  Max_temperature  Min_temperature  Avg_temp
# 41   KISHOREGONJ   2013  18667  ...            31.30             13.2     22.25
# 44     NARSINGDI   2014    269  ...            29.44             11.9     20.67
# 67       TANGAIL   2017   1085  ...            32.00             12.8     22.40
# 26    MYMENSHING   2011  38522  ...            29.60             20.8     25.20
# 60       TANGAIL   2016   1211  ...            30.10             12.3     21.20
# ..            ...   ...    ...  ...              ...              ...       ...
# 19    MYMENSHING   2010  38231  ...            30.70             21.3     26.00
# 49         DHAKA   2015    692  ...            34.20             12.7     23.45
# 50       GAZIPUR   2015   1672  ...            29.00             12.0     20.50
# 25       TANGAIL   2011   1231  ...            22.50             10.1     16.30
# 18       TANGAIL   2010   1045  ...            35.00             10.4     22.70
#
# ...

# %%
data_set2.sort_values(by=['Total Paddy', 'Total Fertilizer'])
# Out:
#          District   Area  ...  Min_temperature  Avg_temp
# 59   narayangonj     153  ...             14.7     22.40
# 66   narayangonj     131  ...             12.2     20.45
# 52   narayangonj      21  ...             15.2     21.75
# 45   narayangonj     150  ...             15.9     24.05
# 17   narayangonj     177  ...             12.8     23.90
# ..            ...    ...  ...              ...       ...
# 61    mymenshing   23288  ...             21.0     25.85
# 54    mymenshing   26570  ...             20.9     25.70
# 34   kishoregonj   18878  ...             11.8     20.60
# 27   kishoregonj   19757  ...             10.8     16.50
# 41   kishoregonj   18667  ...             13.2     22.25
#
# [70 rows x 48 columns]

# %%
data_set2.sort_values(by=['Area'] , ascending = True)
# Out:
#          District   Area  ...  Min_temperature  Avg_temp
# 52   narayangonj      21  ...             15.2     21.75
# 66   narayangonj     131  ...             12.2     20.45
# 58     narsingdi     138  ...             10.3     20.30
# 24   narayangonj     141  ...             12.2     17.80
# 45   narayangonj     150  ...             15.9     24.05
# ..            ...    ...  ...              ...       ...
# 19    mymenshing   38231  ...             21.3     26.00
# 26    mymenshing   38522  ...             20.8     25.20
# 40    mymenshing   39131  ...             20.8     25.40
# 12    mymenshing   39132  ...             21.2     25.84
# 33    mymenshing   39852  ...             20.0     24.80
#
# [70 rows x 48 columns]

# %%
data_set.sample(frac=0.2)
# Out:
#          District  Year   Area  ...  Max_temperature  Min_temperature  Avg_temp
# 2      NARSINGDI   2008    252  ...            34.20             12.5     23.35
# 63         DHAKA   2017    655  ...            31.00             12.7     21.85
# 46       TANGAIL   2014   1176  ...            27.50             12.9     20.20
# 28         DHAKA   2012    525  ...            30.80             12.2     21.50
# 7          DHAKA   2009    492  ...            35.60             14.8     25.20
# 40    MYMENSHING   2013  39131  ...            30.00             20.8     25.40
# 41   KISHOREGONJ   2013  18667  ...            31.30             13.2     22.25
# 61    MYMENSHING   2016  23288  ...            30.70             21.0     25.85
# 68    MYMENSHING   2017  20948  ...            31.00             21.2     26.10
# 3    NARAYANGONJ   2008    185  ...            34.20             12.2     23.20
# 30     NARSINGDI   2012    255  ...            27.00             14.5     20.75
# ...

# %%
data_set.loc[[1,5,10,15]]
# Out:
#          District  Year   Area  ...  Max_temperature  Min_temperature  Avg_temp
# 1        GAZIPUR   2008   2095  ...             30.2             19.5     24.85
# 5     MYMENSHING   2008  38132  ...             29.6             21.6     25.60
# 10   NARAYANGONJ   2009    162  ...             35.6             14.8     25.20
# 15       GAZIPUR   2010   2178  ...             29.7             11.0     20.35
#
# [4 rows x 49 columns]

# %%
data_set.loc[10:25]
# Out:
#          District  Year   Area  ...  Max_temperature  Min_temperature  Avg_temp
# 10   NARAYANGONJ   2009    162  ...            35.60            14.80    25.200
# 11       TANGAIL   2009    972  ...            35.40            12.50    23.950
# 12    MYMENSHING   2009  39132  ...            30.48            21.20    25.840
# 13   KISHOREGONJ   2009  18667  ...            33.00            13.20    23.100
# 14         DHAKA   2010    523  ...            35.50            12.80    24.150
# 15       GAZIPUR   2010   2178  ...            29.70            11.00    20.350
# 16     NARSINGDI   2010    275  ...            35.00            12.80    23.900
# 17   NARAYANGONJ   2010    177  ...            35.00            12.80    23.900
# 18       TANGAIL   2010   1045  ...            35.00            10.40    22.700
# 19    MYMENSHING   2010  38231  ...            30.70            21.30    26.000
# 20   KISHOREGONJ   2010  19567  ...            32.40            11.71    22.055
# ...

# %%
data_set['District']
# Out:
# 0            DHAKA
# 1          GAZIPUR
# 2        NARSINGDI
# 3      NARAYANGONJ
# 4          TANGAIL
#           ...
# 65       NARSINGDI
# 66     NARAYANGONJ
# 67         TANGAIL
# 68      MYMENSHING
# 69     KISHOREGONJ
# Name: District, Length: 70, dtype: object

# %%
 data_set.plot.line(y='Humidity', x='Year',figsize = (25,10))

# %%
data_set3 = data_set.copy()
data_set2.set( xaxis lab )

# %%
data_set2['Total land '].head(10).plot(figsize = (25,10),kind="bar",legend=None);

# %%
data_set3.plot.scatter(figsize = (25,10),x= 'Total Paddy',y= 'Total soil',alpha=1)

# %%
data_set3.groupby(['District']).plot.area(figsize = (15,10),subplots = False,legend=None,xlabel="new x", ylabel="new y")
# Out:
# District
#  DHAKA           AxesSubplot(0.125,0.125;0.775x0.755)
#  GAZIPUR         AxesSubplot(0.125,0.125;0.775x0.755)
#  KISHOREGONJ     AxesSubplot(0.125,0.125;0.775x0.755)
#  MYMENSHING      AxesSubplot(0.125,0.125;0.775x0.755)
#  NARAYANGONJ     AxesSubplot(0.125,0.125;0.775x0.755)
#  NARSINGDI       AxesSubplot(0.125,0.125;0.775x0.755)
#  TANGAIL         AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
data_set3.groupby(['Year'])['Total soil'].sum().plot(figsize = (25,10),kind = 'barh')

# %%
data_set2.head(4).plot.pie(y='Avg_rainfall', labels=["AA", "BB", "CC", "DD"],autopct="%.2f", fontsize=10,  figsize=(20, 15 ))

# %%
data_set3.plot.hexbin(x = 'Area', y = "Total soil",figsize = (20,10) ,gridsize = 20 )

# %%
new_dataset = data_set[['Total Paddy','Avg_rainfall']].copy()

Mean =Total Paddy / Avg_rainfall
dk=pd.new_dataset({"Paddy":Total Paddy,"Distance(KM)":Avg_rainfall,"Velocity":Mean})
# Out:
#   File "<ipython-input-114-8b7724519b23>", line 4
#     Mean =Total Paddy / Avg_rainfall
#                     ^
# SyntaxError: invalid syntax
